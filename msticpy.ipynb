# %%
# !pip install msticpy
# Out:
# ...
#   Using cached msticpy-2.0.0-py3-none-any.whl (772 kB)
# ...
#   Using cached msal_extensions-1.0.0-py2.py3-none-any.whl (19 kB)
# ...
#   Using cached httpx-0.23.0-py3-none-any.whl (84 kB)
# ...
#   Using cached msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# ...
#   Using cached networkx-2.8.5-py3-none-any.whl (2.0 MB)
# ...
#   Using cached geoip2-4.6.0-py2.py3-none-any.whl (26 kB)
# ...
#   Using cached matplotlib-3.5.3-cp310-cp310-win_amd64.whl (7.2 MB)
# ...
#   Using cached azure_mgmt_subscription-3.0.0-py3-none-any.whl (57 kB)
# ...
#   Using cached msrest-0.7.1-py3-none-any.whl (85 kB)
# ...
#   Using cached msal-1.18.0-py2.py3-none-any.whl (82 kB)
# ...
#   Using cached Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# ...
#   Using cached cryptography-37.0.4-cp36-abi3-win_amd64.whl (2.4 MB)
# ...
#   Using cached ipwhois-1.2.0-py2.py3-none-any.whl (73 kB)
# ...
#   Using cached KqlmagicCustom-0.1.114.post21-py3-none-any.whl (238 kB)
# ...
#   Using cached dnspython-2.0.0-py3-none-any.whl (208 kB)
# ...
#   Using cached pygeohash-1.2.0-py2.py3-none-any.whl
# ...

# %%
# !pip install msticpy[azure]
# Out:
# ...
#   Using cached azure_storage_blob-12.13.1-py3-none-any.whl (377 kB)
# ...
#   Using cached azure_mgmt_keyvault-10.1.0-py3-none-any.whl (605 kB)
# ...
#   Using cached azure_mgmt_resourcegraph-8.0.0-py2.py3-none-any.whl (27 kB)
# ...
#   Using cached azure_keyvault_secrets-4.5.1-py3-none-any.whl (290 kB)
# ...
#   Using cached keyring-23.8.2-py3-none-any.whl (34 kB)
# ...
#   Using cached azure_mgmt_resource-21.1.0-py3-none-any.whl (1.8 MB)
# ...
#   Using cached azure_mgmt_monitor-4.0.1-py3-none-any.whl (978 kB)
# ...
#   Using cached azure_mgmt_network-21.0.0-py3-none-any.whl (8.9 MB)
# ...
#   Using cached azure_mgmt_compute-27.2.0-py3-none-any.whl (5.7 MB)
# ...
#   Using cached pywin32_ctypes-0.2.0-py2.py3-none-any.whl (28 kB)
# ...

# %%
import msticpy as mp
# Out:
# This product includes GeoLite2 data created by MaxMind, available from
# <a href="https://www.maxmind.com">https://www.maxmind.com</a>.

# %%
help(mp)
# Out:
# Help on package msticpy:
#
# NAME
#     msticpy - Jupyter and Python Tools for InfoSec.
#
# DESCRIPTION
#     -----------------------------------------------
#
#     Requires Python 3.8 or later.
#
#     To quickly import common modules into a notebook run:
#
#     >>> import msticpy as mp
#     >>> mp.init_notebook()
#
#     If not running in a notebook/IPython use
#     >>> mp.init_notebook(globals())
#
#     To see help on `init_notebook`:
#     >>> help(mp.init_notebook)
#
#     Search msticpy modules for a keyword:
#     >>> mp.search(keyword)
#
#     -----------------------------------------------
#
#     Full documentation is available at:
#     https://msticpy.readthedocs.io
#
#     GitHub repo:
#     https://github.com/microsoft/msticpy
#
#
#     Package structure:
#
#     - analysis - analysis functions
#     - auth - authentication and secrets management
#     - common - utility functions, common types, exceptions
#     - config - configuration tool
# ...

# %%
mp.init_notebook()
# Out:
# This library uses services provided by ipstack.
# <a href="https://ipstack.com">https://ipstack.com</a>
# <p style=''><font color='orange'><h3>Notebook setup completed with some warnings.</h3></p>
# <p style=''>One or more configuration items were missing or set incorrectly.</p>
# <p style=''>Please run the <i>Getting Started Guide for Azure Sentinel ML Notebooks</i> notebook. and the <a href='https://msticpy.readthedocs.io/en/latest/getting_started/msticpyconfig.html'>msticpy configuration guide</a>.</p>
# <p style=''>This notebook may still run but with reduced functionality.</p>

# %%
IpAddress.whois("172.217.14.206")
# Out:
#      asn         asn_cidr asn_country_code    asn_date asn_description  \
# 0  15169  172.217.14.0/24               US  2012-04-16      GOOGLE, US
#
#   asn_registry  \
# 0         arin
#
#                                                                                                   nets  \
# 0  [{'cidr': '172.217.0.0/16', 'name': 'GOOGLE', 'handle': 'NET-172-217-0-0-1', 'range': '172.217.0...
#
#     nir           query   raw raw_referral referral
# 0  None  172.217.14.206  None         None     None

# %%
msticpy.nbwidgets
# Out:
# <module 'msticpy.nbwidgets' from 'C:\\Users\\amit7\\.virtualenvs\\apt38-DWS2QlOc\\lib\\site-packages\\msticpy\\nbwidgets\\__init__.py'>

# %%
msticpy.transform
# Out:
# <module 'msticpy.transform' from 'C:\\Users\\amit7\\.virtualenvs\\apt38-DWS2QlOc\\lib\\site-packages\\msticpy\\transform\\__init__.py'>

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- --------------
# adal                              1.2.7
# aiohttp                           3.8.1
# aiosignal                         1.2.0
# anyio                             3.6.1
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# asttokens                         2.0.7
# async-timeout                     4.0.2
# attrs                             22.1.0
# azure-common                      1.1.28
# azure-core                        1.25.0
# azure-identity                    1.10.0
# azure-keyvault-secrets            4.5.1
# azure-mgmt-compute                27.2.0
# azure-mgmt-core                   1.3.2
# azure-mgmt-keyvault               10.1.0
# azure-mgmt-monitor                4.0.1
# azure-mgmt-network                21.0.0
# azure-mgmt-resource               21.1.0
# azure-mgmt-resourcegraph          8.0.0
# azure-mgmt-subscription           3.0.0
# ...
